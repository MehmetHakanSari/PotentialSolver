# %%
from readairfoil import readairfoil
from airfoil_plotter import plotairfoil, compare_airfoils
import numpy as np

airfoildata = readairfoil('NACAxxxx')
nacanames = [str(i).zfill(4) for i in range(1,10000) if i%100 != 0]
#The user should specify the range of lift coeff for range of alpha. The program will sort it for whole airfoil datas. ,

clcoeff_min = 2.4
alpha_range = [4, 7]
dCl_min = 0.17


max_index_finder = airfoildata['NACA' + str("0001")]["AOA"] <= alpha_range[1]
min_index_finder = airfoildata['NACA' + str("0001")]["AOA"] >= alpha_range[0]
index_finder = max_index_finder & min_index_finder
index_search = np.where(index_finder)[0]

print(index_search)
condition_satisfied_airfoils_names = []

#The program will sort the airfoil datas for the range of lift coeff.
for airfoil_name in nacanames:
    clcoeff_max = airfoildata['NACA' + str(airfoil_name)]["Cl"][index_search].max()
    dclcoeff_min = airfoildata['NACA' + str(airfoil_name)]["dCl"][index_search].min()
    if clcoeff_max >= clcoeff_min and dclcoeff_min >= dCl_min:
        condition_satisfied_airfoils_names.append(airfoil_name)
    

print(condition_satisfied_airfoils_names)
# Out:
# [6]
# ...

# %%
plotairfoil(airfoildata['NACA4412'])
compare_airfoils(airfoildata['NACA4412'], airfoildata['NACA8993'])
